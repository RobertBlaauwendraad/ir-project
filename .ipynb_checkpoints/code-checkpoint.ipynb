# %%
import pyterrier as pt
import pyt_splade
import torch
import transformers

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
splade = pyt_splade.Splade(model="C:/splade_model", device=device)
# Out:
# device(type='cuda')

# %%
import pyterrier as pt
import pyt_splade
import os

warnings.filterwarnings("ignore", message=".*torch.cuda.amp.autocast.*")

splade = pyt_splade.Splade(model="C:/splade_model", device="cuda")
index_dir = os.path.abspath("./msmarco_splade_index")
dataset = pt.get_dataset("irds:msmarco-passage")
indexer = pt.IterDictIndexer(index_dir, pretokenised=True, overwrite=True)
indexing_pipeline = splade.doc_encoder() >> indexer

index_ref = indexing_pipeline.index(dataset.get_corpus_iter(), batch_size=128)
# Out:
# msmarco-passage documents:   0%|          | 0/8841823 [00:00<?, ?it/s]
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:89: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# C:\Users\teunv\anaconda3\envs\ir_project\lib\site-packages\splade\models\transformer_rep.py:32: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast() if self.fp16 else NullContextManager():
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 11
#       8 indexer = pt.IterDictIndexer(index_dir, pretokenised=True, overwrite=True)
#       9 indexing_pipeline = splade.doc_encoder() >> indexer
# ---> 11 index_ref = indexing_pipeline.index(dataset.get_corpus_iter(), batch_size=128)
#
# File ~\anaconda3\envs\ir_project\lib\site-packages\pyterrier\_ops.py:378, in Compose.index(self, iter, batch_size)
#     376     for batch in chunked(iter, batch_size):
#     377         yield from prev_transformer.transform_iter(batch)
# --> 378 return last_transformer.index(gen())
#
# File ~\anaconda3\envs\ir_project\lib\site-packages\pyterrier\utils.py:142, in pre_invocation_decorator.<locals>._decorator_wrapper.<locals>._wrapper(*args, **kwargs)
#     139 @wraps(fn)
#     140 def _wrapper(*args, **kwargs):
#     141     decorator(fn)
# --> 142     return fn(*args, **kwargs)
#
# File ~\anaconda3\envs\ir_project\lib\site-packages\pyterrier\terrier\index.py:678, in _IterDictIndexer_nofifo.index(self, it, fields)
#     676     iter_docs = DocListIterator(self._filter_iterable(it))
#     677     self.index_called = True
# --> 678     indexer.indexDocuments(iter_docs)
#     679     iter_docs = None
#     681 else:
#     682
#     683     # we need to prevent collectionIterator from being GCd
#
# File jnius/jnius_export_class.pxi:1187, in jnius.JavaMultipleMethod.__call__()
#
# File jnius/jnius_export_class.pxi:897, in jnius.JavaMethod.__call__()
#
# File jnius/jnius_export_class.pxi:991, in jnius.JavaMethod.call_method()
#
# File jnius/jnius_utils.pxi:69, in jnius.check_exception()
#
# File jnius/jnius_utils.pxi:100, in jnius._append_exception_trace_messages()
#
# File jnius/jnius_conversion.pxi:159, in jnius.convert_jobject_to_python()
#
# File jnius/jnius_proxy.pxi:154, in jnius.invoke0()
#
# File jnius/jnius_proxy.pxi:82, in jnius.py_invoke0()
#
# File <frozen importlib._bootstrap>:408, in parent(self)
#
# File jnius/jnius_proxy.pxi:154, in jnius.invoke0()
#
# File jnius/jnius_proxy.pxi:124, in jnius.py_invoke0()
#
# File jnius/jnius_proxy.pxi:50, in jnius.PythonJavaClass.invoke()
#
# File jnius/jnius_proxy.pxi:76, in jnius.PythonJavaClass._invoke()
#
# File ~\anaconda3\envs\ir_project\lib\site-packages\pyterrier\utils.py:142, in pre_invocation_decorator.<locals>._decorator_wrapper.<locals>._wrapper(*args, **kwargs)
#     139 @wraps(fn)
#     140 def _wrapper(*args, **kwargs):
#     141     decorator(fn)
# --> 142     return fn(*args, **kwargs)
#
# File ~\anaconda3\envs\ir_project\lib\site-packages\pyterrier\terrier\java.py:177, in TerrierJavaInit._post_init_index.<locals>.DocListIterator.next(self)
#     174 @jnius.java_method('()Ljava/lang/Object;')
#     175 def next(self):
#     176     try:
# --> 177         doc_dict = next(self.pyiterator)
#     178     except StopIteration:
#     179         self.hasnext = False
#
# File ~\anaconda3\envs\ir_project\lib\site-packages\pyterrier\terrier\index.py:617, in <genexpr>(.0)
#     612     self._validate_doc_dict(first_docs[0])
#     614 # important: return an iterator (i.e. using a generator expression) here, rather than make this
#     615 # function a generator, to be sure that the validation above happens when  _filter_iterable is
#     616 # called, rather than on the first invocation of next()
# --> 617 return ({f: doc[f] for f in all_cols} for doc in it)
#
# File ~\anaconda3\envs\ir_project\lib\site-packages\pyterrier\_ops.py:377, in Compose.index.<locals>.gen()
#     375 def gen():
#     376     for batch in chunked(iter, batch_size):
# --> 377         yield from prev_transformer.transform_iter(batch)
#
# File ~\anaconda3\envs\ir_project\lib\site-packages\pyterrier\_ops.py:383, in Compose.transform_iter(self, inp)
#     381 out = inp
#     382 for transformer in self._transformers:
# --> 383     out = transformer.transform_iter(out)
#     384 return out
#
# File ~\anaconda3\envs\ir_project\lib\site-packages\pyterrier\transformer.py:136, in Transformer.transform_iter(self, inp)
#     115 """
#     116     Abstract method that runs the transformer over iterable input (such as lists or generators),
#     117     where each element is a dictionary record. This or :meth:`transform`
#    (...)
#     133     :rtype: ``Iterable[Dict]``
#     134 """
#     135 # We should have no recursive transform <-> transform_iter problem, due to the __new__ check.
# --> 136 return self.transform(pd.DataFrame(list(inp))).to_dict(orient='records')
#
# File ~\anaconda3\envs\ir_project\lib\site-packages\pyt_splade\_encoder.py:52, in SpladeEncoder.transform(self, df)
#      50 res = []
#      51 for batch in more_itertools.chunked(it, self.batch_size):
# ---> 52     res.extend(self.splade.encode(batch, self.rep, format='dict' if self.sparse else 'np', scale=self.scale))
#      53 return df.assign(**{self.out_field: res})
#
# File ~\anaconda3\envs\ir_project\lib\site-packages\pyt_splade\_model.py:116, in Splade.encode(self, texts, rep, format, scale)
#     114     reps = reps * scale
#     115 if format == 'dict':
# --> 116     reps = reps.cpu()
#     117     for i in range(reps.shape[0]):
#     118         # get the number of non-zero dimensions in the rep:
#     119         col = torch.nonzero(reps[i]).squeeze(1).tolist()
#
# KeyboardInterrupt:

# %%
import pyterrier as pt
from pyterrier.measures import *
import pandas as pd

dataset = pt.get_dataset("msmarco_passage")

index_ref = dataset.get_index("terrier_stemmed")
bm25 = pt.terrier.Retriever(index_ref, wmodel="BM25", verbose=True)

topics = dataset.get_topics('dev.small')
topics['query'] = topics['query'].str.replace(r'[\?\:\!]', '', regex=True)
qrels = dataset.get_qrels('dev.small')

experiment = pt.Experiment(
    [bm25],
    topics,
    qrels,
    [nDCG@10, MAP, Recall@100]
)

print(experiment)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 8
#       5 dataset = pt.get_dataset("msmarco_passage")
#       7 index_ref = dataset.get_index("terrier_stemmed")
# ----> 8 bm25 = pt.terrier.Retriever(index_ref, wmodel="BM25", verbose=True)
#      10 topics = dataset.get_topics('dev.small')
#      11 topics['query'] = topics['query'].str.replace(r'[\?\:\!]', '', regex=True)
#
# File ~\anaconda3\envs\new-python-env\Lib\site-packages\pyterrier\utils.py:141, in pre_invocation_decorator.<locals>._decorator_wrapper.<locals>._wrapper(*args, **kwargs)
#     139 @wraps(fn)
#     140 def _wrapper(*args, **kwargs):
# --> 141     decorator(fn)
#     142     return fn(*args, **kwargs)
#
# File ~\anaconda3\envs\new-python-env\Lib\site-packages\pyterrier\java\_utils.py:35, in required(fn)
#      33 if not _started:
#      34     trigger = fn.__qualname__ if hasattr(fn, '__qualname__') else fn.__name__
# ---> 35     _init(trigger=trigger)
#
# File ~\anaconda3\envs\new-python-env\Lib\site-packages\pyterrier\utils.py:25, in once.<locals>._once.<locals>._wrapper(*args, **kwargs)
#      23     raise ValueError(f"{fn.__name__} has already been run")
#      24 # how to handle errors?
# ---> 25 res = fn(*args, **kwargs)
#      26 called = True
#      27 return res
#
# File ~\anaconda3\envs\new-python-env\Lib\site-packages\pyterrier\java\_utils.py:127, in _init(trigger)
#     124 for _, initializer in initializers:
#     125     initializer.pre_init(jnius_config)
# --> 127 import jnius # noqa: PT100
#     128 _started = True
#     130 # run post-initialization setup
#
# File ~\anaconda3\envs\new-python-env\Lib\site-packages\jnius\__init__.py:36
#      34 try:
#      35     from .jnius import *  # noqa
# ---> 36     from .reflect import *  # noqa
#      37 except Exception as e:
#      38     pass
#
# File ~\anaconda3\envs\new-python-env\Lib\site-packages\jnius\reflect.py:19
#      14 __all__ = ('autoclass', 'ensureclass', 'protocol_map')
#      16 log = logging.getLogger('kivy').getChild(__name__)
# ---> 19 class Class(JavaClass, metaclass=MetaJavaClass):
#      20     __javaclass__ = 'java/lang/Class'
#      22     desiredAssertionStatus = JavaMethod('()Z')
#
# File jnius/jnius_export_class.pxi:126, in jnius.MetaJavaClass.__new__()
#
# File jnius/jnius_export_class.pxi:183, in jnius.MetaJavaClass.resolve_class()
#
# File jnius/jnius_env.pxi:11, in jnius.get_jnienv()
#
# File jnius/jnius_jvm_desktop.pxi:91, in jnius.get_platform_jnienv()
#
# File jnius/jnius_jvm_desktop.pxi:64, in jnius.create_jnienv()
#
# File ~\anaconda3\envs\new-python-env\Lib\os.py:1137, in _AddedDllDirectory.__exit__(self, *args)
#    1136 def __exit__(self, *args):
# -> 1137     self.close()
#
# File ~\anaconda3\envs\new-python-env\Lib\os.py:1131, in _AddedDllDirectory.close(self)
#    1129     self._cookie = cookie
#    1130     self._remove_dll_directory = remove_dll_directory
# -> 1131 def close(self):
#    1132     self._remove_dll_directory(self._cookie)
#    1133     self.path = None
#
# KeyboardInterrupt:

# %%
import sys
sys.executable
# Out:
# 'C:\\Users\\teunv\\anaconda3\\envs\\ir_project\\python.exe'

# %%
# !python -c "from transformers import pipeline; print(pipeline('sentiment-analysis')('hugging face is the best'))"
# Out:
# [{'label': 'POSITIVE', 'score': 0.999839186668396}]
# No model was supplied, defaulted to distilbert-base-uncased-finetuned-sst-2-english (https://huggingface.co/distilbert-base-uncased-finetuned-sst-2-english)
#
# Downloading:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Downloading: 100%|##########| 629/629 [00:00<?, ?B/s]
#
# Downloading:   0%|          | 0.00/255M [00:00<?, ?B/s]
# Downloading:   1%|1         | 2.57M/255M [00:00<00:09, 26.7MB/s]
# Downloading:   4%|3         | 8.95M/255M [00:00<00:05, 48.9MB/s]
# Downloading:   6%|6         | 16.1M/255M [00:00<00:04, 60.6MB/s]
# Downloading:   9%|9         | 23.2M/255M [00:00<00:03, 66.1MB/s]
# Downloading:  12%|#1        | 30.5M/255M [00:00<00:03, 69.7MB/s]
# Downloading:  15%|#4        | 37.6M/255M [00:00<00:03, 71.3MB/s]
# Downloading:  18%|#7        | 44.8M/255M [00:00<00:03, 72.7MB/s]
# Downloading:  20%|##        | 52.0M/255M [00:00<00:02, 73.4MB/s]
# Downloading:  23%|##3       | 59.0M/255M [00:00<00:02, 72.7MB/s]
# Downloading:  26%|##5       | 66.2M/255M [00:01<00:02, 73.4MB/s]
# Downloading:  29%|##8       | 73.2M/255M [00:01<00:02, 73.0MB/s]
# Downloading:  31%|###1      | 80.3M/255M [00:01<00:02, 73.3MB/s]
# Downloading:  34%|###4      | 87.3M/255M [00:01<00:02, 71.0MB/s]
# Downloading:  37%|###6      | 94.4M/255M [00:01<00:02, 72.0MB/s]
# Downloading:  40%|###9      | 102M/255M [00:01<00:02, 73.0MB/s]
# Downloading:  43%|####2     | 109M/255M [00:01<00:02, 73.6MB/s]
# Downloading:  45%|####5     | 116M/255M [00:01<00:01, 74.0MB/s]
# Downloading:  48%|####8     | 123M/255M [00:01<00:01, 73.9MB/s]
# Downloading:  51%|#####     | 130M/255M [00:01<00:01, 74.1MB/s]
# Downloading:  54%|#####3    | 137M/255M [00:02<00:01, 72.7MB/s]
# Downloading:  56%|#####6    | 144M/255M [00:02<00:01, 72.9MB/s]
# Downloading:  59%|#####9    | 151M/255M [00:02<00:01, 72.5MB/s]
# Downloading:  62%|######1   | 158M/255M [00:02<00:01, 73.2MB/s]
# Downloading:  65%|######4   | 165M/255M [00:02<00:01, 73.9MB/s]
# Downloading:  68%|######7   | 173M/255M [00:02<00:01, 74.5MB/s]
# Downloading:  70%|#######   | 180M/255M [00:02<00:01, 74.6MB/s]
# Downloading:  73%|#######3  | 187M/255M [00:02<00:00, 74.5MB/s]
# Downloading:  76%|#######6  | 194M/255M [00:02<00:00, 74.6MB/s]
# Downloading:  79%|#######8  | 202M/255M [00:02<00:00, 74.7MB/s]
# Downloading:  82%|########1 | 209M/255M [00:03<00:00, 74.6MB/s]
# Downloading:  84%|########4 | 216M/255M [00:03<00:00, 74.5MB/s]
# Downloading:  87%|########7 | 223M/255M [00:03<00:00, 74.4MB/s]
# Downloading:  90%|######### | 230M/255M [00:03<00:00, 74.4MB/s]
# Downloading:  93%|#########2| 237M/255M [00:03<00:00, 74.7MB/s]
# Downloading:  96%|#########5| 245M/255M [00:03<00:00, 75.1MB/s]
# Downloading:  99%|#########8| 252M/255M [00:03<00:00, 75.5MB/s]
# Downloading: 100%|##########| 255M/255M [00:03<00:00, 72.4MB/s]
#
# Downloading:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# Downloading: 100%|##########| 48.0/48.0 [00:00<00:00, 47.9kB/s]
#
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:  78%|#######8  | 177k/226k [00:00<00:00, 1.80MB/s]
# Downloading: 100%|##########| 226k/226k [00:00<00:00, 1.41MB/s]
